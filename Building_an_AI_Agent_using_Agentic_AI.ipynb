# %% [markdown]
# Agentic AI refers to artificial intelligence systems that can perceive their environment, make decisions, and act autonomously to achieve a goal. These agents typically use reinforcement learning (RL) methods to optimize their behaviour over time through interactions with an environment.

# %% [markdown]
# #Understanding the Components of Agentic AI
#
# Agentic AI involves several key components. In this article, I’ll be building an AI Agent for trading. So, let’s understand the key components of Agentic AI with our example:
#
#
# *   The Agent: The agent is the decision-making entity in the AI system. In our case, the DQN trading agent will be responsible for making trading decisions based on market data.
# *   The Environment: The environment is the external system in which the agent operates. Our trading environment will consist of stock market data, where the agent will interact with price movements and execute trades
# *   The State: The state represents the information available to the agent at any given time. Our trading agent’s state includes the stock’s closing price, moving averages, and daily returns.
# *   The Action Space: The action space defines what actions the agent can take. Our trading agent has three possible actions: Buy, Sell, and Hold.
# *   The Reward Function: The reward function determines the agent’s performance by assigning a numerical value to its actions. The goal of our trading agent will be to maximize total profit by the end of the trading session.

# %% [markdown]
# #Building an AI Agent using Agentic AI: Getting Started
#
# Now, let’s get started with building an AI Agent for trading using Agentic AI. I’ll first import all the necessary Python libraries and collect Apple’s stock market data from Yahoo Finance:

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# define stock symbol and time period
symbol = "AAPL"
start_date = "2020-01-01"
end_date = "2025-02-14"

# download historical data
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# /tmp/ipython-input-2026925277.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Now, we will calculate technical indicators that help the AI agent make better trading decisions:

# %%
# feature engineering
data['SMA_5'] = data['Close'].rolling(window=5).mean()
data['SMA_20'] = data['Close'].rolling(window=20).mean()
data['Returns'] = data['Close'].pct_change()

# %% [markdown]
# Now, let’s drop missing values and reset the index:

# %%
# drop NaN values and reset index
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Next, we will define the action space. The AI agent has three possible actions:
# *   HOLD: Do nothing.
# *   BUY: Purchase stocks.
# *   SELL: Sell held stocks.

# %%
# define action space
ACTIONS = {0: "HOLD", 1: "BUY", 2: "SELL"}

# %% [markdown]
# This action space is used to train the reinforcement learning model.

# %%
# get state function
def get_state(data, index):
    return np.array([
        float(data.loc[index, 'Close']),
        float(data.loc[index, 'SMA_5']),
        float(data.loc[index, 'SMA_20']),
        float(data.loc[index, 'Returns'])
    ])

# %% [markdown]
# This function extracts the state representation from the dataset at a given time index. The state is an array containing:
#
#
# *   Closing price
# *   5-day SMA
# *   20-day SMA
# *   Daily return percentage
#
# This numerical representation of the stock market is fed into the AI model to make trading decisions.

# %% [markdown]
# #Building The Trading Environment for our AI Agent
# We will now define a trading environment to interact with the Deep Q-Network (DQN) AI agent, which will allow it to learn how to trade stocks profitably:

# %%
# trading environment
class TradingEnvironment:
    def __init__(self, data):
        self.data = data
        self.initial_balance = 10000
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0

    def reset(self):
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0
        return get_state(self.data, self.index)

    def step(self, action):
        price = float(self.data.loc[self.index, 'Close'])
        reward = 0

        if action == 1 and self.balance >= price:  # BUY
            self.holdings = self.balance // price
            self.balance -= self.holdings * price
        elif action == 2 and self.holdings > 0:  # SELL
            self.balance += self.holdings * price
            self.holdings = 0

        self.index += 1
        done = self.index >= len(self.data) - 1

        if done:
            reward = self.balance - self.initial_balance

        next_state = get_state(self.data, self.index) if not done else None
        return next_state, reward, done, {}

# %% [markdown]
# The environment is implemented as a class that simulates the stock market. It tracks the agent’s balance, holdings, and current market index, and it provides new states and rewards in response to the agent’s actions.

# %% [markdown]
# #The Deep Q-Network (DQN)
#
# DQN is a neural network that approximates the Q-values for each state-action pair. We will now define the neural network architecture for our Deep Q-Network. It will be responsible for predicting the best trading actions based on the stock market state:

# %%
# deep q-network
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# Here we built a Deep Q-Network using PyTorch to optimize stock trading decisions. The model features a three-layer neural network to predict trading actions, leveraging ReLU activation to enhance learning efficiency.
#
# It outputs Q-values, which the agent utilizes to determine the best action: buy, sell, or hold, based on market conditions.

# %% [markdown]
# #The DQN Agent
# Now, we will implement the AI agent that learns how to trade stocks using Deep Q-Learning. The DQN Agent will interact with the trading environment, make trading decisions (BUY, SELL, HOLD), store experiences, and learn from past experiences to improve future decisions:

# %%
# DQN agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(list(ACTIONS.keys()))
        state = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state)
        return torch.argmax(q_values).item()

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)

        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
                target += self.gamma * torch.max(self.model(next_state_tensor)).item()

            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            target_tensor = self.model(state_tensor).clone().detach()
            target_tensor[0][action] = target

            self.optimizer.zero_grad()
            output = self.model(state_tensor)
            loss = self.criterion(output, target_tensor)
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# So, we developed a Deep Q-Learning Agent to interact with the stock market environment to enhance its decision-making through Experience Replay, which stores and reuses past experiences for training. The agent effectively balances Exploration vs. Exploitation, taking random actions initially and making smarter decisions as learning progresses.
#
# Training is performed using batches of past experiences to refine the neural network’s performance. Additionally, a discount factor (gamma) is applied to weigh immediate and future rewards, to ensure long-term profitability.

# %% [markdown]
# #Training the AI Agent
# Training involves running multiple episodes where the agent interacts with the environment, learns from experience, and updates its model. Let’s train the agent:

# %%
# train the agent
env = TradingEnvironment(data)
agent = DQNAgent(state_size=4, action_size=3)
batch_size = 32
episodes = 500
total_rewards = []

for episode in range(episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

    agent.replay(batch_size)
    total_rewards.append(total_reward)
    print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")

print("Training Complete!")
# Out:
# /tmp/ipython-input-3109401411.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# /tmp/ipython-input-3109401411.py:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# /tmp/ipython-input-3109401411.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# /tmp/ipython-input-3109401411.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# /tmp/ipython-input-2218621516.py:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close'])
# Episode 1/500, Total Reward: -9919.781455993652
# Episode 2/500, Total Reward: -9838.241394042969
# Episode 3/500, Total Reward: -9883.975749969482
# Episode 4/500, Total Reward: -9862.71078491211
# Episode 5/500, Total Reward: -9879.37572479248
# Episode 6/500, Total Reward: -9877.683658599854
# Episode 7/500, Total Reward: -9763.430305480957
# Episode 8/500, Total Reward: -9871.222709655762
# Episode 9/500, Total Reward: -9795.829498291016
# Episode 10/500, Total Reward: 15319.600498199463
# Episode 11/500, Total Reward: -9736.481422424316
# Episode 12/500, Total Reward: -9994.495178222656
# Episode 13/500, Total Reward: -9845.898014068604
# Episode 14/500, Total Reward: -9942.768802642822
# Episode 15/500, Total Reward: -9927.362991333008
# Episode 16/500, Total Reward: -9803.498107910156
# Episode 17/500, Total Reward: -9805.909469604492
# Episode 18/500, Total Reward: -9921.577087402344
# Episode 19/500, Total Reward: 12017.002643585205
# Episode 20/500, Total Reward: -9956.584255218506
# Episode 21/500, Total Reward: -9869.225700378418
# Episode 22/500, Total Reward: 4092.1845207214355
# Episode 23/500, Total Reward: -9835.932075500488
# Episode 24/500, Total Reward: -9795.057861328125
# Episode 25/500, Total Reward: -9877.766292572021
# Episode 26/500, Total Reward: 2765.223976135254
# Episode 27/500, Total Reward: -9882.690444946289
# Episode 28/500, Total Reward: -9846.898452758789
# Episode 29/500, Total Reward: -9805.073753356934
# Episode 30/500, Total Reward: -9825.974411010742
# Episode 31/500, Total Reward: -9832.238582611084
# Episode 32/500, Total Reward: -9846.340015411377
# Episode 33/500, Total Reward: 18182.423316955566
# Episode 34/500, Total Reward: -9866.49785232544
# Episode 35/500, Total Reward: 802.6826934814453
# Episode 36/500, Total Reward: -9807.747997283936
# Episode 37/500, Total Reward: -9881.374599456787
# Episode 38/500, Total Reward: -9871.209201812744
# Episode 39/500, Total Reward: -9836.302154541016
# Episode 40/500, Total Reward: -9873.613010406494
# Episode 41/500, Total Reward: -9885.634204864502
# Episode 42/500, Total Reward: -9757.281311035156
# Episode 43/500, Total Reward: -9870.622814178467
# Episode 44/500, Total Reward: -9853.01335144043
# Episode 45/500, Total Reward: -9831.838478088379
# Episode 46/500, Total Reward: -9819.246231079102
# Episode 47/500, Total Reward: -9819.681591033936
# Episode 48/500, Total Reward: 5162.881553649902
# Episode 49/500, Total Reward: -9808.644577026367
# Episode 50/500, Total Reward: -9922.397624969482
# Episode 51/500, Total Reward: -9780.04373550415
# Episode 52/500, Total Reward: 1873.6901359558105
# Episode 53/500, Total Reward: -9776.422695159912
# Episode 54/500, Total Reward: -9857.593200683594
# Episode 55/500, Total Reward: -9843.65357208252
# Episode 56/500, Total Reward: 9448.17070388794
# Episode 57/500, Total Reward: 5347.58890914917
# Episode 58/500, Total Reward: -9828.800094604492
# Episode 59/500, Total Reward: -9829.5485496521
# Episode 60/500, Total Reward: -9808.221855163574
# Episode 61/500, Total Reward: -9824.283721923828
# Episode 62/500, Total Reward: 7387.67041015625
# Episode 63/500, Total Reward: -9785.978607177734
# Episode 64/500, Total Reward: -9827.648262023926
# Episode 65/500, Total Reward: -9913.807300567627
# Episode 66/500, Total Reward: -9796.885578155518
# Episode 67/500, Total Reward: 194.51302337646484
# Episode 68/500, Total Reward: -9835.164249420166
# Episode 69/500, Total Reward: -9985.366798400879
# Episode 70/500, Total Reward: -9937.12741470337
# Episode 71/500, Total Reward: -9907.648006439209
# Episode 72/500, Total Reward: -9798.53984451294
# Episode 73/500, Total Reward: -9803.872562408447
# Episode 74/500, Total Reward: -9840.268013000488
# Episode 75/500, Total Reward: -9856.741729736328
# Episode 76/500, Total Reward: -9929.300075531006
# Episode 77/500, Total Reward: -9889.332786560059
# Episode 78/500, Total Reward: -9808.239013671875
# Episode 79/500, Total Reward: -9981.792572021484
# Episode 80/500, Total Reward: -9813.296165466309
# Episode 81/500, Total Reward: -9863.997425079346
# Episode 82/500, Total Reward: -9779.36990737915
# Episode 83/500, Total Reward: 25269.636714935303
# Episode 84/500, Total Reward: -9963.075538635254
# Episode 85/500, Total Reward: 4365.513008117676
# Episode 86/500, Total Reward: -9916.096858978271
# Episode 87/500, Total Reward: -9803.646041870117
# Episode 88/500, Total Reward: -9793.56986618042
# Episode 89/500, Total Reward: -9829.070583343506
# Episode 90/500, Total Reward: -9787.040214538574
# Episode 91/500, Total Reward: -9881.673698425293
# Episode 92/500, Total Reward: -9956.943172454834
# Episode 93/500, Total Reward: -9747.457809448242
# Episode 94/500, Total Reward: 5238.632495880127
# Episode 95/500, Total Reward: -9860.58243560791
# Episode 96/500, Total Reward: -9925.209205627441
# Episode 97/500, Total Reward: -9889.945983886719
# Episode 98/500, Total Reward: -9742.750930786133
# Episode 99/500, Total Reward: -9848.01001739502
# Episode 100/500, Total Reward: -9880.624382019043
# Episode 101/500, Total Reward: -9904.781410217285
# Episode 102/500, Total Reward: -9993.412105560303
# Episode 103/500, Total Reward: 8647.685363769531
# Episode 104/500, Total Reward: 3516.234664916992
# Episode 105/500, Total Reward: -9776.225448608398
# Episode 106/500, Total Reward: -9933.021881103516
# Episode 107/500, Total Reward: -9874.653610229492
# Episode 108/500, Total Reward: -9923.049766540527
# Episode 109/500, Total Reward: -9956.433235168457
# Episode 110/500, Total Reward: 20351.70445251465
# Episode 111/500, Total Reward: -9757.05937576294
# Episode 112/500, Total Reward: -9817.60899734497
# Episode 113/500, Total Reward: -9860.810092926025
# Episode 114/500, Total Reward: -9748.731845855713
# Episode 115/500, Total Reward: -9824.539295196533
# Episode 116/500, Total Reward: -9841.960571289062
# Episode 117/500, Total Reward: -9814.848140716553
# Episode 118/500, Total Reward: -9898.894065856934
# Episode 119/500, Total Reward: 11803.069702148438
# Episode 120/500, Total Reward: -9941.815254211426
# Episode 121/500, Total Reward: -9782.6096534729
# Episode 122/500, Total Reward: -9817.77816772461
# Episode 123/500, Total Reward: -9852.474952697754
# Episode 124/500, Total Reward: 12089.713638305664
# Episode 125/500, Total Reward: -9840.741859436035
# Episode 126/500, Total Reward: -9823.95964050293
# Episode 127/500, Total Reward: -9821.263507843018
# Episode 128/500, Total Reward: -9786.420166015625
# Episode 129/500, Total Reward: 3737.466697692871
# Episode 130/500, Total Reward: 1605.608310699463
# Episode 131/500, Total Reward: -9773.081439971924
# Episode 132/500, Total Reward: -9801.345294952393
# Episode 133/500, Total Reward: -9859.362335205078
# Episode 134/500, Total Reward: -9963.951950073242
# Episode 135/500, Total Reward: -9918.56672668457
# Episode 136/500, Total Reward: -9823.696292877197
# Episode 137/500, Total Reward: -9984.137958526611
# Episode 138/500, Total Reward: -9893.408405303955
# Episode 139/500, Total Reward: -9920.398002624512
# Episode 140/500, Total Reward: -9797.340427398682
# Episode 141/500, Total Reward: -9940.874824523926
# Episode 142/500, Total Reward: -9814.5823097229
# Episode 143/500, Total Reward: 23190.183723449707
# Episode 144/500, Total Reward: -9827.344459533691
# Episode 145/500, Total Reward: -9937.787742614746
# Episode 146/500, Total Reward: 1095.6462440490723
# Episode 147/500, Total Reward: -9881.552257537842
# Episode 148/500, Total Reward: -9895.85718536377
# Episode 149/500, Total Reward: 7042.206211090088
# Episode 150/500, Total Reward: 3848.6722869873047
# Episode 151/500, Total Reward: -9941.210697174072
# Episode 152/500, Total Reward: 4374.523971557617
# Episode 153/500, Total Reward: -9871.621765136719
# Episode 154/500, Total Reward: 21680.29452896118
# Episode 155/500, Total Reward: -9848.233451843262
# Episode 156/500, Total Reward: -9872.759143829346
# Episode 157/500, Total Reward: -9865.087383270264
# Episode 158/500, Total Reward: -9999.69075012207
# Episode 159/500, Total Reward: 301.6345558166504
# Episode 160/500, Total Reward: -9976.180530548096
# Episode 161/500, Total Reward: -9814.783660888672
# Episode 162/500, Total Reward: -9992.653907775879
# Episode 163/500, Total Reward: -9890.888977050781
# Episode 164/500, Total Reward: -9908.591506958008
# Episode 165/500, Total Reward: -9944.80973815918
# Episode 166/500, Total Reward: -9975.613800048828
# Episode 167/500, Total Reward: -9937.841312408447
# Episode 168/500, Total Reward: -9879.674270629883
# Episode 169/500, Total Reward: -9994.40432357788
# Episode 170/500, Total Reward: -9934.36978149414
# Episode 171/500, Total Reward: -9783.80904006958
# Episode 172/500, Total Reward: 1583.8015022277832
# Episode 173/500, Total Reward: -9871.747417449951
# Episode 174/500, Total Reward: -9897.161437988281
# Episode 175/500, Total Reward: 5176.655303955078
# Episode 176/500, Total Reward: -9870.26693725586
# Episode 177/500, Total Reward: 2200.1530952453613
# Episode 178/500, Total Reward: -9806.510604858398
# Episode 179/500, Total Reward: -9798.695850372314
# Episode 180/500, Total Reward: -9848.64437866211
# Episode 181/500, Total Reward: -9791.670585632324
# Episode 182/500, Total Reward: -9896.698062896729
# Episode 183/500, Total Reward: -9891.71552658081
# Episode 184/500, Total Reward: -2955.517749786377
# Episode 185/500, Total Reward: -9743.4172706604
# Episode 186/500, Total Reward: -9861.14323425293
# Episode 187/500, Total Reward: -9891.788372039795
# Episode 188/500, Total Reward: -9839.974544525146
# Episode 189/500, Total Reward: 18675.584411621094
# Episode 190/500, Total Reward: -9913.381778717041
# Episode 191/500, Total Reward: -961.2093658447266
# Episode 192/500, Total Reward: -9983.283432006836
# Episode 193/500, Total Reward: -9909.14139175415
# Episode 194/500, Total Reward: -9802.417808532715
# Episode 195/500, Total Reward: -9891.236854553223
# Episode 196/500, Total Reward: -9933.38516998291
# Episode 197/500, Total Reward: -9983.594337463379
# Episode 198/500, Total Reward: 8233.887344360352
# Episode 199/500, Total Reward: -9952.367767333984
# Episode 200/500, Total Reward: -9781.372547149658
# Episode 201/500, Total Reward: -9792.91514968872
# Episode 202/500, Total Reward: -9950.35837173462
# Episode 203/500, Total Reward: 5795.072250366211
# Episode 204/500, Total Reward: -9832.411979675293
# Episode 205/500, Total Reward: 6298.446731567383
# Episode 206/500, Total Reward: -9814.193294525146
# Episode 207/500, Total Reward: 10691.456604003906
# Episode 208/500, Total Reward: 13857.594093322754
# Episode 209/500, Total Reward: -9828.41044998169
# Episode 210/500, Total Reward: -9805.894458770752
# Episode 211/500, Total Reward: 3832.285041809082
# Episode 212/500, Total Reward: -9802.585956573486
# Episode 213/500, Total Reward: -9749.306617736816
# Episode 214/500, Total Reward: 4746.602096557617
# Episode 215/500, Total Reward: -882.5794639587402
# Episode 216/500, Total Reward: -9835.843673706055
# Episode 217/500, Total Reward: -9800.209106445312
# Episode 218/500, Total Reward: -1031.2408409118652
# Episode 219/500, Total Reward: -9835.454818725586
# Episode 220/500, Total Reward: -9783.632041931152
# Episode 221/500, Total Reward: -9841.12688446045
# Episode 222/500, Total Reward: -9990.787757873535
# Episode 223/500, Total Reward: -9920.233589172363
# Episode 224/500, Total Reward: -724.0639114379883
# Episode 225/500, Total Reward: -9866.544033050537
# Episode 226/500, Total Reward: -9841.48376083374
# Episode 227/500, Total Reward: -1073.5253677368164
# Episode 228/500, Total Reward: -9935.385509490967
# Episode 229/500, Total Reward: -9872.762599945068
# Episode 230/500, Total Reward: -9870.325908660889
# Episode 231/500, Total Reward: 1317.2481117248535
# Episode 232/500, Total Reward: -9831.495018005371
# Episode 233/500, Total Reward: -9904.487106323242
# Episode 234/500, Total Reward: -277.502197265625
# Episode 235/500, Total Reward: 757.2297744750977
# Episode 236/500, Total Reward: -9999.147399902344
# Episode 237/500, Total Reward: -9829.402938842773
# Episode 238/500, Total Reward: 1363.920181274414
# Episode 239/500, Total Reward: -77.79072570800781
# Episode 240/500, Total Reward: -2571.1506423950195
# Episode 241/500, Total Reward: 3037.488628387451
# Episode 242/500, Total Reward: 1299.9911880493164
# Episode 243/500, Total Reward: -1246.303466796875
# Episode 244/500, Total Reward: -9891.83895111084
# Episode 245/500, Total Reward: -2783.361083984375
# Episode 246/500, Total Reward: -3124.523036956787
# Episode 247/500, Total Reward: 7635.637977600098
# Episode 248/500, Total Reward: 13170.673278808594
# Episode 249/500, Total Reward: -1839.9759407043457
# Episode 250/500, Total Reward: 5771.141891479492
# Episode 251/500, Total Reward: -9874.262886047363
# Episode 252/500, Total Reward: -9775.48461151123
# Episode 253/500, Total Reward: 15363.026775360107
# Episode 254/500, Total Reward: 1795.0940742492676
# Episode 255/500, Total Reward: 1742.111888885498
# Episode 256/500, Total Reward: -9965.245071411133
# Episode 257/500, Total Reward: -330.7290229797363
# Episode 258/500, Total Reward: -9761.914459228516
# Episode 259/500, Total Reward: -528.0789070129395
# Episode 260/500, Total Reward: -9887.480667114258
# Episode 261/500, Total Reward: -9928.288417816162
# Episode 262/500, Total Reward: -926.969841003418
# Episode 263/500, Total Reward: -9845.817199707031
# Episode 264/500, Total Reward: 8709.800582885742
# Episode 265/500, Total Reward: 797.4813041687012
# Episode 266/500, Total Reward: -9761.12133026123
# Episode 267/500, Total Reward: -9940.03572845459
# Episode 268/500, Total Reward: -9913.773544311523
# Episode 269/500, Total Reward: -9934.750171661377
# Episode 270/500, Total Reward: -9982.178932189941
# Episode 271/500, Total Reward: -9784.602416992188
# Episode 272/500, Total Reward: -9918.787586212158
# Episode 273/500, Total Reward: -9853.999862670898
# Episode 274/500, Total Reward: -9967.87654876709
# Episode 275/500, Total Reward: -9988.890922546387
# Episode 276/500, Total Reward: -9990.826602935791
# Episode 277/500, Total Reward: -9935.098693847656
# Episode 278/500, Total Reward: -9881.581954956055
# Episode 279/500, Total Reward: -9987.150302886963
# Episode 280/500, Total Reward: -9995.742347717285
# Episode 281/500, Total Reward: -9985.47280883789
# Episode 282/500, Total Reward: -9889.772407531738
# Episode 283/500, Total Reward: -9994.629791259766
# Episode 284/500, Total Reward: -9856.444938659668
# Episode 285/500, Total Reward: -9837.363502502441
# Episode 286/500, Total Reward: -9993.154388427734
# Episode 287/500, Total Reward: -9839.878196716309
# Episode 288/500, Total Reward: -9907.701435089111
# Episode 289/500, Total Reward: -9737.824798583984
# Episode 290/500, Total Reward: 27624.154499053955
# Episode 291/500, Total Reward: 9288.416847229004
# Episode 292/500, Total Reward: -9939.769332885742
# Episode 293/500, Total Reward: -9871.073291778564
# Episode 294/500, Total Reward: -9866.547454833984
# Episode 295/500, Total Reward: 1049.017375946045
# Episode 296/500, Total Reward: 1688.5367584228516
# Episode 297/500, Total Reward: 2323.3537216186523
# Episode 298/500, Total Reward: 307.0446472167969
# Episode 299/500, Total Reward: -1603.0987930297852
# Episode 300/500, Total Reward: -9853.47915649414
# Episode 301/500, Total Reward: 207.91142654418945
# Episode 302/500, Total Reward: -2342.1216430664062
# Episode 303/500, Total Reward: 591.3283500671387
# Episode 304/500, Total Reward: 3083.434898376465
# Episode 305/500, Total Reward: 1149.4337043762207
# Episode 306/500, Total Reward: -9909.550701141357
# Episode 307/500, Total Reward: -1222.9616470336914
# Episode 308/500, Total Reward: -9852.174324035645
# Episode 309/500, Total Reward: -2590.493808746338
# Episode 310/500, Total Reward: -737.0639801025391
# Episode 311/500, Total Reward: 1803.858985900879
# Episode 312/500, Total Reward: -9781.725128173828
# Episode 313/500, Total Reward: -426.86413192749023
# Episode 314/500, Total Reward: 5459.818199157715
# Episode 315/500, Total Reward: 69.88211822509766
# Episode 316/500, Total Reward: -1273.6967315673828
# Episode 317/500, Total Reward: -9922.587356567383
# Episode 318/500, Total Reward: -825.1908340454102
# Episode 319/500, Total Reward: 2929.2913246154785
# Episode 320/500, Total Reward: -9934.407772064209
# Episode 321/500, Total Reward: 3448.6563835144043
# Episode 322/500, Total Reward: -988.9197845458984
# Episode 323/500, Total Reward: 249.43673706054688
# Episode 324/500, Total Reward: 3556.184398651123
# Episode 325/500, Total Reward: 3199.6996459960938
# Episode 326/500, Total Reward: 1774.7674674987793
# Episode 327/500, Total Reward: 2313.1048889160156
# Episode 328/500, Total Reward: 688.185661315918
# Episode 329/500, Total Reward: 434.79338455200195
# Episode 330/500, Total Reward: -9787.179512023926
# Episode 331/500, Total Reward: -553.9507331848145
# Episode 332/500, Total Reward: -1780.5472450256348
# Episode 333/500, Total Reward: -9956.674987792969
# Episode 334/500, Total Reward: -9935.044673919678
# Episode 335/500, Total Reward: 2698.850845336914
# Episode 336/500, Total Reward: -642.4500198364258
# Episode 337/500, Total Reward: 2140.342544555664
# Episode 338/500, Total Reward: 2564.280990600586
# Episode 339/500, Total Reward: 2725.704490661621
# Episode 340/500, Total Reward: 2995.987274169922
# Episode 341/500, Total Reward: -9868.225513458252
# Episode 342/500, Total Reward: 100.0036392211914
# Episode 343/500, Total Reward: 292.9309844970703
# Episode 344/500, Total Reward: -1269.784034729004
# Episode 345/500, Total Reward: -9988.782188415527
# Episode 346/500, Total Reward: 452.80857849121094
# Episode 347/500, Total Reward: -1000.416576385498
# Episode 348/500, Total Reward: 4781.79122543335
# Episode 349/500, Total Reward: -9933.883312225342
# Episode 350/500, Total Reward: -1482.6961669921875
# Episode 351/500, Total Reward: -9846.932434082031
# Episode 352/500, Total Reward: 2697.127960205078
# Episode 353/500, Total Reward: 2762.7257690429688
# Episode 354/500, Total Reward: -139.6063346862793
# Episode 355/500, Total Reward: 1608.4210243225098
# Episode 356/500, Total Reward: 15384.500328063965
# Episode 357/500, Total Reward: 14826.981410980225
# Episode 358/500, Total Reward: -9966.065055847168
# Episode 359/500, Total Reward: 17844.811100006104
# Episode 360/500, Total Reward: 1718.1185150146484
# Episode 361/500, Total Reward: 4783.554138183594
# Episode 362/500, Total Reward: 7211.611968994141
# Episode 363/500, Total Reward: -9998.085750579834
# Episode 364/500, Total Reward: 4789.834823608398
# Episode 365/500, Total Reward: -9827.63150024414
# Episode 366/500, Total Reward: -910.3726921081543
# Episode 367/500, Total Reward: 3910.036361694336
# Episode 368/500, Total Reward: 2777.235668182373
# Episode 369/500, Total Reward: -862.9391708374023
# Episode 370/500, Total Reward: -430.39315032958984
# Episode 371/500, Total Reward: -69.03445816040039
# Episode 372/500, Total Reward: 414.56786346435547
# Episode 373/500, Total Reward: 2203.31339263916
# Episode 374/500, Total Reward: 1706.0119857788086
# Episode 375/500, Total Reward: 198.24642181396484
# Episode 376/500, Total Reward: 427.5587387084961
# Episode 377/500, Total Reward: -9811.758777618408
# Episode 378/500, Total Reward: -572.9894523620605
# Episode 379/500, Total Reward: -9803.082012176514
# Episode 380/500, Total Reward: -703.0676803588867
# Episode 381/500, Total Reward: 1685.504005432129
# Episode 382/500, Total Reward: 2750.817481994629
# Episode 383/500, Total Reward: 2348.8952674865723
# Episode 384/500, Total Reward: -9864.603115081787
# Episode 385/500, Total Reward: -9950.075340270996
# Episode 386/500, Total Reward: 369.4086227416992
# Episode 387/500, Total Reward: 3297.8131103515625
# Episode 388/500, Total Reward: -857.0075225830078
# Episode 389/500, Total Reward: -774.9557037353516
# Episode 390/500, Total Reward: -9930.636058807373
# Episode 391/500, Total Reward: 1623.158790588379
# Episode 392/500, Total Reward: -843.6956405639648
# Episode 393/500, Total Reward: 2435.6222038269043
# Episode 394/500, Total Reward: 2891.454879760742
# Episode 395/500, Total Reward: -341.4792251586914
# Episode 396/500, Total Reward: 4463.204132080078
# Episode 397/500, Total Reward: 1214.606346130371
# Episode 398/500, Total Reward: -9907.0680809021
# Episode 399/500, Total Reward: -522.438533782959
# Episode 400/500, Total Reward: 2854.1714096069336
# Episode 401/500, Total Reward: -9866.468688964844
# Episode 402/500, Total Reward: -2887.643898010254
# Episode 403/500, Total Reward: -9780.48844909668
# Episode 404/500, Total Reward: -1027.6470489501953
# Episode 405/500, Total Reward: 3934.1973876953125
# Episode 406/500, Total Reward: 1027.2118911743164
# Episode 407/500, Total Reward: -939.894775390625
# Episode 408/500, Total Reward: 5127.48637008667
# Episode 409/500, Total Reward: 2280.193031311035
# Episode 410/500, Total Reward: 2093.6313858032227
# Episode 411/500, Total Reward: 7536.115936279297
# Episode 412/500, Total Reward: -9879.579093933105
# Episode 413/500, Total Reward: 1882.833511352539
# Episode 414/500, Total Reward: -371.0899772644043
# Episode 415/500, Total Reward: 1384.737621307373
# Episode 416/500, Total Reward: 2920.906562805176
# Episode 417/500, Total Reward: 5040.872161865234
# Episode 418/500, Total Reward: -9759.19213104248
# Episode 419/500, Total Reward: 5779.283496856689
# Episode 420/500, Total Reward: 4073.845687866211
# Episode 421/500, Total Reward: 1536.6036682128906
# Episode 422/500, Total Reward: -9829.224082946777
# Episode 423/500, Total Reward: -140.93807220458984
# Episode 424/500, Total Reward: -9932.499229431152
# Episode 425/500, Total Reward: -185.3585968017578
# Episode 426/500, Total Reward: 1026.962245941162
# Episode 427/500, Total Reward: 2361.702766418457
# Episode 428/500, Total Reward: 372.1577682495117
# Episode 429/500, Total Reward: 645.539421081543
# Episode 430/500, Total Reward: -9848.85442352295
# Episode 431/500, Total Reward: -9815.41999053955
# Episode 432/500, Total Reward: 1389.1040802001953
# Episode 433/500, Total Reward: 2960.942092895508
# Episode 434/500, Total Reward: 20257.79875946045
# Episode 435/500, Total Reward: -9844.44758605957
# Episode 436/500, Total Reward: -9904.359508514404
# Episode 437/500, Total Reward: -9994.207786560059
# Episode 438/500, Total Reward: -9842.568542480469
# Episode 439/500, Total Reward: -9842.649436950684
# Episode 440/500, Total Reward: -9875.16678237915
# Episode 441/500, Total Reward: 672.5427322387695
# Episode 442/500, Total Reward: -506.8721923828125
# Episode 443/500, Total Reward: 3862.2500762939453
# Episode 444/500, Total Reward: -9769.613578796387
# Episode 445/500, Total Reward: -9782.69839477539
# Episode 446/500, Total Reward: 170.33343505859375
# Episode 447/500, Total Reward: -9995.672309875488
# Episode 448/500, Total Reward: -9992.436050415039
# Episode 449/500, Total Reward: -9895.050304412842
# Episode 450/500, Total Reward: -9856.356460571289
# Episode 451/500, Total Reward: -9773.642349243164
# Episode 452/500, Total Reward: -9831.81600189209
# Episode 453/500, Total Reward: 3223.984748840332
# Episode 454/500, Total Reward: -9989.71683883667
# Episode 455/500, Total Reward: -9998.767288208008
# Episode 456/500, Total Reward: -9938.575733184814
# Episode 457/500, Total Reward: -9867.532638549805
# Episode 458/500, Total Reward: -9984.886833190918
# Episode 459/500, Total Reward: -1282.9428215026855
# Episode 460/500, Total Reward: -9899.232460021973
# Episode 461/500, Total Reward: 1713.3184814453125
# Episode 462/500, Total Reward: -9854.083656311035
# Episode 463/500, Total Reward: -9932.433307647705
# Episode 464/500, Total Reward: -9872.575485229492
# Episode 465/500, Total Reward: -9906.071418762207
# Episode 466/500, Total Reward: 7642.332458496094
# Episode 467/500, Total Reward: -9865.12841796875
# Episode 468/500, Total Reward: -9788.177833557129
# Episode 469/500, Total Reward: -9836.528392791748
# Episode 470/500, Total Reward: -9999.815631866455
# Episode 471/500, Total Reward: -907.5434150695801
# Episode 472/500, Total Reward: -9854.481468200684
# Episode 473/500, Total Reward: 6142.10107421875
# Episode 474/500, Total Reward: -9984.751670837402
# Episode 475/500, Total Reward: -9890.960464477539
# Episode 476/500, Total Reward: -9951.835678100586
# Episode 477/500, Total Reward: -9847.998893737793
# Episode 478/500, Total Reward: 7782.25256729126
# Episode 479/500, Total Reward: 5190.721187591553
# Episode 480/500, Total Reward: -9842.710021972656
# Episode 481/500, Total Reward: 1495.0565872192383
# Episode 482/500, Total Reward: -9823.909996032715
# Episode 483/500, Total Reward: 9933.572952270508
# Episode 484/500, Total Reward: 14077.994770050049
# Episode 485/500, Total Reward: -9925.483016967773
# Episode 486/500, Total Reward: -9908.39289855957
# Episode 487/500, Total Reward: -9797.701763153076
# Episode 488/500, Total Reward: -9792.734115600586
# Episode 489/500, Total Reward: 9347.757873535156
# Episode 490/500, Total Reward: -9779.663375854492
# Episode 491/500, Total Reward: -9812.955837249756
# Episode 492/500, Total Reward: -9889.720909118652
# Episode 493/500, Total Reward: -9852.31562423706
# Episode 494/500, Total Reward: -9922.05670928955
# Episode 495/500, Total Reward: -9804.984050750732
# Episode 496/500, Total Reward: 5210.563201904297
# Episode 497/500, Total Reward: -9907.938301086426
# Episode 498/500, Total Reward: 1165.5740051269531
# Episode 499/500, Total Reward: -9995.560810089111
# Episode 500/500, Total Reward: -9862.849563598633
# Training Complete!

# %% [markdown]
# Here, we trained the AI Trading Agent using Deep Q-Learning, simulating 500 trading sessions where the agent learned from experience. It leveraged Exploration & Exploitation, initially taking random actions before making more informed decisions as training progressed.
#
# Experience Replay is used to store past experiences, allowing the neural network to learn through batch training. Throughout the process, we tracked rewards to measure the agent’s performance improvements over time.
#
# After training, we can test the agent on new market data by allowing it to make decisions without random exploration:

# %%
# create a fresh environment instance for testing
test_env = TradingEnvironment(data)
state = test_env.reset()
done = False

# simulate a trading session using the trained agent
while not done:
    # always choose the best action (exploitation)
    action = agent.act(state)
    next_state, reward, done, _ = test_env.step(action)
    state = next_state if next_state is not None else state

final_balance = test_env.balance
profit = final_balance - test_env.initial_balance
print(f"Final Balance after testing: ${final_balance:.2f}")
print(f"Total Profit: ${profit:.2f}")
# Out:
# /tmp/ipython-input-3109401411.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# /tmp/ipython-input-3109401411.py:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# /tmp/ipython-input-3109401411.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# /tmp/ipython-input-3109401411.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# /tmp/ipython-input-2218621516.py:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close'])
# Final Balance after testing: $13991.17
# Total Profit: $3991.17

# %% [markdown]
# The agent started with $10,000  and ended with $13991.17 Profit = $3991.17, meaning the agent made a small but positive return.

# %% [markdown]
# #Summary
# So, in this article, we explored how to build an AI trading agent using Agentic AI and Deep Q-Learning, enabling it to make autonomous trading decisions. After training, our AI agent successfully generated a small but positive profit, which demonstrates its ability to navigate market fluctuations.
